# %%
import pandas as pd
from sage.all import *
from itertools import combinations

vhod = "2del_geodesic_SA.csv"
izhod = "pregledovanje_lastnosti_geodesic.csv"


# -------------------------------------------------
# inducirani cikli dolžine 3,4,5,6
# -------------------------------------------------
def induced_cycles(G, lengths=(3,4,5,6)):
    """
    Vrne seznam ciklov (kot množice vozlišč),
    inducirani cikli za podane dolžine.
    """
    V = G.vertices()
    cycles = []

    for k in lengths:
        for S in combinations(V, k):
            H = G.subgraph(S)
            if H.is_connected() and H.size() == k:
                if all(d == 2 for d in H.degree()):
                    cycles.append(set(S))

    return cycles


# -------------------------------------------------
# KAKTUS
# -------------------------------------------------
def is_cactus(G):
    cycles = G.cycle_basis()
    for i in range(len(cycles)):
        for j in range(i + 1, len(cycles)):
            if len(set(cycles[i]) & set(cycles[j])) > 1:
                return False
    return True


# -------------------------------------------------
# PTC (na osnovi induciranih ciklov)
# -------------------------------------------------
def is_PTC_from_cycles(cycles):
    for i in range(len(cycles)):
        for j in range(i + 1, len(cycles)):
            if len(cycles[i] & cycles[j]) > 2:
                return False
    return True


# -------------------------------------------------
# obdelava CSV
# -------------------------------------------------
def obdelaj_csv(vhod, izhod, mode="both"):

    df = pd.read_csv(vhod, dtype=str, keep_default_na=False)

    if mode in ("min", "both"):
        df["PTC_min"] = ""
        df["KAKTUS_min"] = ""
        df["DVODELEN_min"] = ""
        df["MAX_DEG_min"] = ""
        for k in [3,4,5,6]:
            df[f"C{k}_min"] = ""

    if mode in ("max", "both"):
        df["PTC_max"] = ""
        df["KAKTUS_max"] = ""
        df["DVODELEN_max"] = ""
        df["MAX_DEG_max"] = ""
        for k in [3,4,5,6]:
            df[f"C{k}_max"] = ""

    for i, row in df.iterrows():

        # ---------- MIN ----------
        if mode in ("min", "both"):
            try:
                G = Graph(row["graph6_min"])
                cycles = induced_cycles(G)

                df.at[i, "PTC_min"] = str(is_PTC_from_cycles(cycles)).lower()
                df.at[i, "KAKTUS_min"] = str(is_cactus(G)).lower()
                df.at[i, "DVODELEN_min"] = str(G.is_bipartite()).lower()
                df.at[i, "MAX_DEG_min"] = max(G.degree())

                for k in [3,4,5,6]:
                    df.at[i, f"C{k}_min"] = sum(1 for c in cycles if len(c) == k)

            except:
                df.at[i, "PTC_min"] = "false"
                df.at[i, "KAKTUS_min"] = "false"
                df.at[i, "DVODELEN_min"] = "false"
                df.at[i, "MAX_DEG_min"] = ""
                for k in [3,4,5,6]:
                    df.at[i, f"C{k}_min"] = ""

        # ---------- MAX ----------
        if mode in ("max", "both"):
            try:
                G = Graph(row["graph6_max"])
                cycles = induced_cycles(G)

                df.at[i, "PTC_max"] = str(is_PTC_from_cycles(cycles)).lower()
                df.at[i, "KAKTUS_max"] = str(is_cactus(G)).lower()
                df.at[i, "DVODELEN_max"] = str(G.is_bipartite()).lower()
                df.at[i, "MAX_DEG_max"] = max(G.degree())

                for k in [3,4,5,6]:
                    df.at[i, f"C{k}_max"] = sum(1 for c in cycles if len(c) == k)

            except:
                df.at[i, "PTC_max"] = "false"
                df.at[i, "KAKTUS_max"] = "false"
                df.at[i, "DVODELEN_max"] = "false"
                df.at[i, "MAX_DEG_max"] = ""
                for k in [3,4,5,6]:
                    df.at[i, f"C{k}_max"] = ""

    df.to_csv(izhod, index=False)
    return df


obdelaj_csv(vhod, izhod, mode="both")
# Out:
#       n µ(G) min geodesic max geodesic  \
# 0     3    1            6            6
# 1     4    1           10           12
# 2     5    1           15           18
# 3     6    1           21           26
# 4     7    1           28           35
# ..   ..  ...          ...          ...
# 205  26    8          351         4035
# 206  27    8          378         4835
# 207  28    8          406         5930
# 208  29    8          435         6694
# 209  30    8          465         7562
#
#                                             slika_min  \
# 0     slike_geodesic_min/graf_geodesic_min_mu1_n3.png
# 1     slike_geodesic_min/graf_geodesic_min_mu1_n4.png
# 2     slike_geodesic_min/graf_geodesic_min_mu1_n5.png
# 3     slike_geodesic_min/graf_geodesic_min_mu1_n6.png
# 4     slike_geodesic_min/graf_geodesic_min_mu1_n7.png
# ..                                                ...
# 205  slike_geodesic_min/graf_geodesic_min_mu8_n26.png
# 206  slike_geodesic_min/graf_geodesic_min_mu8_n27.png
# 207  slike_geodesic_min/graf_geodesic_min_mu8_n28.png
# 208  slike_geodesic_min/graf_geodesic_min_mu8_n29.png
# 209  slike_geodesic_min/graf_geodesic_min_mu8_n30.png
#
#                                             slika_max  \
# 0     slike_geodesic_max/graf_geodesic_max_mu1_n3.png
# 1     slike_geodesic_max/graf_geodesic_max_mu1_n4.png
# 2     slike_geodesic_max/graf_geodesic_max_mu1_n5.png
# 3     slike_geodesic_max/graf_geodesic_max_mu1_n6.png
# 4     slike_geodesic_max/graf_geodesic_max_mu1_n7.png
# ..                                                ...
# 205  slike_geodesic_max/graf_geodesic_max_mu8_n26.png
# 206  slike_geodesic_max/graf_geodesic_max_mu8_n27.png
# 207  slike_geodesic_max/graf_geodesic_max_mu8_n28.png
# 208  slike_geodesic_max/graf_geodesic_max_mu8_n29.png
# 209  slike_geodesic_max/graf_geodesic_max_mu8_n30.png
#
#                                             graph6_min  \
# 0                                                   Bw
# 1                                                   CV
# 2                                                  DC{
# 3                                                 E?bw
# 4                                                F?AFw
# ..                                                 ...
# 205  YCOccf~O??_@?@??_?G?@??C??G??G??C??@???G???_??...
# 206  ZCOccf~O??_@?@??_?G?@??C??G??G??C??@???G???_??...
# 207  [COccf~O??_@?@??_?G?@??C??G??G??C??@???G???_??...
# 208  \COccf~O??_@?@??_?G?@??C??G??G??C??@???G???_??...
# 209  ]COccf~O??_@?@??_?G?@??C??G??G??C??@???G???_??...
#
#                                             graph6_max PTC_min KAKTUS_min  \
# 0                                                   Bw    true       true
# 1                                                   C]    true       true
# 2                                                  DEw    true       true
# 3                                                 E?zO    true       true
# 4                                                F?`v?    true       true
# ..                                                 ...     ...        ...
# 205  Y??O?AA_c_C_?M?K??AEAQO??C?O??GO???A??A__????C...    true      false
# 206  Z??O?AA_c_C_?M?K??AEAQO??C?O??GO???a??A_G?????...    true      false
# 207  [??o??A_c_???M?K??AEAQO??C?O??GO???_??A_G?G???...    true      false
# 208  \??o??A_c_???M?K??AEAQO??C?O??GO???_??A_G?G???...    true      false
# 209  ]??O??B_c_???E?K??AEAQO?C??O??GO???_??A_??G???...    true      false
#
#      ... C5_min C6_min PTC_max KAKTUS_max DVODELEN_max MAX_DEG_max C3_max  \
# 0    ...      0      0    true       true        false           2      1
# 1    ...      0      0    true       true         true           2      0
# 2    ...      0      0    true       true         true           3      0
# 3    ...      0      0    true       true         true           3      0
# 4    ...      0      0    true       true         true           3      0
# ..   ...    ...    ...     ...        ...          ...         ...    ...
# 205  ...      0      0   false      false         true           4      0
# 206  ...      0      0   false      false         true           4      0
# 207  ...      0      0   false      false         true           4      0
# 208  ...      0      0   false      false         true           5      0
# 209  ...      0      0   false      false         true           4      0
#
#     C4_max C5_max C6_max
# 0        0      0      0
# 1        1      0      0
# 2        1      0      0
# 3        1      0      0
# 4        1      0      0
# ..     ...    ...    ...
# 205     13      0      0
# 206     13      0      0
# 207     10      0      0
# 208     10      0      0
# 209     10      0      0
#
# [210 rows x 24 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# naloži CSV
df = pd.read_csv("pregledovanje_lastnosti_geodesic.csv")

# poskrbi za pravilne tipe
df["µ(G)"] = df["µ(G)"].astype(int)
df["MAX_DEG_min"] = df["MAX_DEG_min"].astype(int)
df["MAX_DEG_max"] = df["MAX_DEG_max"].astype(int)

# agregacija po µ
agg = df.groupby("µ(G)").agg(
    max_deg_min=("MAX_DEG_min", "mean"),
    max_deg_max=("MAX_DEG_max", "mean")
).reset_index()

# graf
plt.figure(figsize=(7,5))
plt.plot(agg["µ(G)"], agg["max_deg_min"], marker="o", label="min primer")
plt.plot(agg["µ(G)"], agg["max_deg_max"], marker="s", label="max primer")

plt.xlabel("µ(G)")
plt.ylabel("Maksimalna stopnja grafa")
plt.title("Maksimalna stopnja v odvisnosti od µ(G)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# naloži podatke
df = pd.read_csv("pregledovanje_lastnosti_geodesic.csv")

# tipi
df["n"] = df["n"].astype(int)
df["µ(G)"] = df["µ(G)"].astype(int)
df["C3_min"] = df["C3_min"].astype(int)

plt.figure(figsize=(7,5))

for mu in sorted(df["µ(G)"].unique()):
    sub = df[df["µ(G)"] == mu].sort_values("n")
    plt.plot(sub["n"], sub["C3_min"], marker="o", label=f"µ = {mu}")

plt.xlabel("n")
plt.ylabel("Število ciklov dolžine 3 (C3) – min grafi")
plt.title("C3 v min grafih v odvisnosti od n in µ(G)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("pregledovanje_lastnosti_geodesic.csv")

# tipi
df["n"] = df["n"].astype(int)
df["µ(G)"] = df["µ(G)"].astype(int)
df["MAX_DEG_max"] = pd.to_numeric(df["MAX_DEG_max"], errors="coerce")

plt.figure(figsize=(7,5))

for mu in sorted(df["µ(G)"].unique()):
    sub = df[df["µ(G)"] == mu].sort_values("n")
    plt.plot(
        sub["n"],
        sub["MAX_DEG_max"],
        marker="o",
        label=f"µ = {mu}"
    )

plt.xlabel("Število vozlišč n")
plt.ylabel("Maksimalna stopnja grafa (MAX grafi)")
plt.title("Maksimalna stopnja MAX grafov v odvisnosti od n in µ(G)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
